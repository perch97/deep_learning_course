# %% [markdown]
# <a href="https://colab.research.google.com/github/perch97/deep_learning_course/blob/main/shw_03_rnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Глубинное обучение 1 / Введение в глубинное обучение, ФКН ВШЭ
#
# ## Домашнее задание 3: RNN и языковые модели
#
# ### Общая информация
#
# Оценка после штрафа после мягкого дедлайна вычисляется по формуле $M_{\text{penalty}} = M_{\text{full}} \cdot 0.85^{t/1440}$, где $M_{\text{full}}$ — полная оценка за работу без учета штрафа, а $t$ — время в минутах, прошедшее после мягкого дедлайна (округление до двух цифр после запятой). Таким образом, спустя первые сутки после мягкого дедлайна вы не можете получить оценку выше 12.75, а если сдать через четыре дня после мягкого дедлайна, то ваш максимум — 7.83 балла.
#
# ### Оценивание и штрафы
#
# Максимально допустимая оценка за работу — 15 баллов. Сдавать задание после указанного срока сдачи нельзя.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов. Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник в отдельном блоке в конце вашей работы (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# Неэффективная реализация кода может негативно отразиться на оценке. Также оценка может быть снижена за плохо читаемый код и плохо оформленные графики. Все ответы должны сопровождаться кодом или комментариями о том, как они были получены.
#
# ### О задании
#
# В этом задании вам предстоит обучить рекуррентную нейронную сеть для задачи генерации текстов. В качестве данных возьмем набор из 120 тысяч анекдотов (всех категорий от А до Я включительно). Его вы можете найти в архиве `jokes.txt.zip`, который доступен по [ссылке](https://disk.yandex.com/d/fjt5xICH-ukEEA).

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Задание 1: Dataset (1 балл)
#
# В этом задании мы будет пользоваться библиотекой [sentencepiece](https://github.com/google/sentencepiece), которая поддерживает разные форматы токенизации текстов, в том числе BPE, который мы и будем использовать. Реализуйте недостающие фрагменты кода в классе `TextDataset` в файле `dataset.py`. Датасет обучает sentencepiece токенизатор, токенизирует тексты, превращает токены в индексы и паддит до одной и той же длины (параметр `max_length`). Не забудьте, что для генерации текстов нам будут нужны специальные токены начала и конца последовательности, соответственно `BOS` и `EOS`. Существуют еще два специальных токена &mdash; паддинг `PAD` и токен `UNK`, заменяющий out-of-vocabulary токены.

# %%
# !pip install sentencepiece
# Out:
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.1.99)

# %%
import torch

import numpy as np
import dataset
from dataset import TextDataset

# %%
train_set = dataset.TextDataset(data_file='jokes.txt', train=True, sp_model_prefix='bpe')
valid_set = dataset.TextDataset(data_file='jokes.txt', train=False, sp_model_prefix='bpe')

# %%
train_set.ids2text([1000])
# Out:
# 'ребен'

# %%
train_set.ids2text([100])
# Out:
# 'ча'

# %%
# Код должен проходить тесты
assert len(train_set) + len(valid_set) == 120759
for i in range(10):
    for i in range(9):
        for i in range(5):
            for dataset in (train_set, valid_set):
                indices, length = dataset[np.random.randint(len(dataset))]

                assert indices.shape == (dataset.max_length, )
                assert indices[0].item() == dataset.bos_id
                assert (indices == dataset.eos_id).sum().item() == 1

                eos_pos = indices.tolist().index(dataset.eos_id)
                assert torch.all(indices[eos_pos + 1:] == dataset.pad_id)
                #print('Indices: ',indices)
                #print('dataset.pad_id: ',dataset.pad_id)
                print(i)
                print('length: ',length)
                print((indices != dataset.pad_id).sum())

                assert (indices != dataset.pad_id).sum() == length
# Out:
# 0
# length:  48
# tensor(48)
# 0
# length:  44
# tensor(44)
# 1
# length:  35
# tensor(35)
# 1
# length:  50
# tensor(50)
# 2
# length:  31
# tensor(31)
# 2
# length:  30
# tensor(30)
# 3
# length:  41
# tensor(41)
# 3
# length:  41
# tensor(41)
# 4
# length:  26
# tensor(26)
# 4
# length:  20
# tensor(20)
# 0
# length:  41
# tensor(41)
# 0
# length:  24
# tensor(24)
# 1
# length:  38
# tensor(38)
# 1
# length:  31
# tensor(31)
# 2
# length:  17
# tensor(17)
# 2
# length:  14
# tensor(14)
# 3
# length:  82
# tensor(82)
# 3
# length:  30
# tensor(30)
# 4
# length:  69
# tensor(69)
# 4
# length:  32
# tensor(32)
# 0
# length:  23
# tensor(23)
# 0
# length:  25
# tensor(25)
# 1
# length:  47
# tensor(47)
# 1
# length:  31
# tensor(31)
# 2
# length:  14
# tensor(14)
# 2
# length:  27
# tensor(27)
# 3
# length:  36
# tensor(36)
# 3
# length:  28
# tensor(28)
# 4
# length:  42
# tensor(42)
# 4
# length:  20
# tensor(20)
# 0
# length:  31
# tensor(31)
# 0
# length:  48
# tensor(48)
# 1
# length:  71
# tensor(71)
# 1
# length:  29
# tensor(29)
# 2
# length:  43
# tensor(43)
# 2
# length:  44
# tensor(44)
# 3
# length:  33
# tensor(33)
# 3
# length:  57
# tensor(57)
# 4
# length:  25
# tensor(25)
# 4
# length:  31
# tensor(31)
# 0
# length:  55
# tensor(55)
# 0
# length:  35
# tensor(35)
# 1
# length:  29
# tensor(29)
# 1
# length:  40
# tensor(40)
# 2
# length:  62
# tensor(62)
# 2
# length:  27
# tensor(27)
# 3
# length:  29
# tensor(29)
# 3
# length:  95
# tensor(95)
# 4
# length:  37
# tensor(37)
# 4
# length:  50
# tensor(50)
# 0
# length:  25
# tensor(25)
# 0
# length:  105
# tensor(105)
# 1
# length:  29
# tensor(29)
# 1
# length:  19
# tensor(19)
# 2
# length:  27
# tensor(27)
# 2
# length:  20
# tensor(20)
# 3
# length:  31
# tensor(31)
# 3
# length:  45
# tensor(45)
# 4
# length:  82
# tensor(82)
# 4
# length:  23
# tensor(23)
# 0
# length:  34
# tensor(34)
# 0
# length:  43
# tensor(43)
# 1
# length:  37
# tensor(37)
# 1
# length:  15
# tensor(15)
# 2
# length:  61
# tensor(61)
# 2
# length:  25
# tensor(25)
# 3
# length:  46
# tensor(46)
# 3
# length:  29
# tensor(29)
# 4
# length:  35
# tensor(35)
# 4
# length:  29
# tensor(29)
# 0
# length:  46
# tensor(46)
# 0
# length:  23
# tensor(23)
# 1
# length:  32
# tensor(32)
# 1
# length:  48
# tensor(48)
# 2
# length:  41
# tensor(41)
# 2
# length:  27
# tensor(27)
# 3
# length:  20
# tensor(20)
# 3
# length:  39
# tensor(39)
# 4
# length:  31
# tensor(31)
# 4
# length:  45
# tensor(45)
# 0
# length:  13
# tensor(13)
# 0
# length:  31
# tensor(31)
# 1
# length:  37
# tensor(37)
# 1
# length:  34
# tensor(34)
# 2
# length:  33
# tensor(33)
# 2
# length:  30
# tensor(30)
# 3
# length:  30
# tensor(30)
# 3
# length:  54
# tensor(54)
# 4
# length:  51
# tensor(51)
# 4
# length:  15
# tensor(15)
# 0
# length:  32
# tensor(32)
# 0
# length:  33
# tensor(33)
# 1
# length:  40
# tensor(40)
# 1
# length:  23
# tensor(23)
# 2
# length:  41
# tensor(41)
# 2
# length:  78
# tensor(78)
# 3
# length:  35
# tensor(35)
# 3
# length:  18
# tensor(18)
# 4
# length:  36
# tensor(36)
# 4
# length:  20
# tensor(20)
# 0
# length:  39
# tensor(39)
# 0
# length:  40
# tensor(40)
# 1
# length:  26
# tensor(26)
# 1
# length:  66
# tensor(66)
# 2
# length:  26
# tensor(26)
# 2
# length:  18
# tensor(18)
# 3
# length:  29
# tensor(29)
# 3
# length:  19
# tensor(19)
# 4
# length:  60
# tensor(60)
# 4
# length:  25
# tensor(25)
# 0
# length:  33
# tensor(33)
# 0
# length:  60
# tensor(60)
# 1
# length:  30
# tensor(30)
# 1
# length:  25
# tensor(25)
# 2
# length:  48
# tensor(48)
# 2
# length:  27
# tensor(27)
# 3
# length:  39
# tensor(39)
# 3
# length:  42
# tensor(42)
# 4
# length:  61
# tensor(61)
# 4
# length:  26
# tensor(26)
# 0
# length:  40
# tensor(40)
# 0
# length:  19
# tensor(19)
# 1
# length:  45
# tensor(45)
# 1
# length:  19
# tensor(19)
# 2
# length:  26
# tensor(26)
# 2
# length:  19
# tensor(19)
# 3
# length:  51
# tensor(51)
# 3
# length:  28
# tensor(28)
# 4
# length:  33
# tensor(33)
# 4
# length:  41
# tensor(41)
# 0
# length:  22
# tensor(22)
# 0
# length:  35
# tensor(35)
# 1
# length:  43
# tensor(43)
# 1
# length:  34
# tensor(34)
# 2
# length:  35
# tensor(35)
# 2
# length:  40
# tensor(40)
# 3
# length:  54
# tensor(54)
# 3
# length:  31
# tensor(31)
# 4
# length:  52
# tensor(52)
# 4
# length:  36
# tensor(36)
# 0
# length:  46
# tensor(46)
# 0
# length:  44
# tensor(44)
# 1
# length:  44
# tensor(44)
# 1
# length:  38
# tensor(38)
# 2
# length:  23
# tensor(23)
# 2
# length:  45
# tensor(45)
# 3
# length:  39
# tensor(39)
# 3
# length:  27
# tensor(27)
# 4
# length:  24
# tensor(24)
# 4
# length:  55
# tensor(55)
# 0
# length:  28
# tensor(28)
# 0
# length:  21
# tensor(21)
# 1
# length:  40
# tensor(40)
# 1
# length:  44
# tensor(44)
# 2
# length:  37
# tensor(37)
# 2
# length:  124
# tensor(124)
# 3
# length:  25
# tensor(25)
# 3
# length:  34
# tensor(34)
# 4
# length:  34
# tensor(34)
# 4
# length:  26
# tensor(26)
# 0
# length:  37
# tensor(37)
# 0
# length:  56
# tensor(56)
# 1
# length:  77
# tensor(77)
# 1
# length:  29
# tensor(29)
# 2
# length:  39
# tensor(39)
# 2
# length:  24
# tensor(24)
# 3
# length:  23
# tensor(23)
# 3
# length:  31
# tensor(31)
# 4
# length:  35
# tensor(35)
# 4
# length:  18
# tensor(18)
# 0
# length:  22
# tensor(22)
# 0
# length:  67
# tensor(67)
# 1
# length:  30
# tensor(30)
# 1
# length:  18
# tensor(18)
# 2
# length:  40
# tensor(40)
# 2
# length:  63
# tensor(63)
# 3
# length:  42
# tensor(42)
# 3
# length:  23
# tensor(23)
# 4
# length:  53
# tensor(53)
# 4
# length:  39
# tensor(39)
# 0
# length:  20
# tensor(20)
# 0
# length:  60
# tensor(60)
# 1
# length:  28
# tensor(28)
# 1
# length:  52
# tensor(52)
# 2
# length:  50
# tensor(50)
# 2
# length:  21
# tensor(21)
# 3
# length:  23
# tensor(23)
# 3
# length:  33
# tensor(33)
# 4
# length:  56
# tensor(56)
# 4
# length:  21
# tensor(21)
# 0
# length:  56
# tensor(56)
# 0
# length:  32
# tensor(32)
# 1
# length:  54
# tensor(54)
# 1
# length:  25
# tensor(25)
# 2
# length:  44
# tensor(44)
# 2
# length:  17
# tensor(17)
# 3
# length:  49
# tensor(49)
# 3
# length:  54
# tensor(54)
# 4
# length:  21
# tensor(21)
# 4
# length:  20
# tensor(20)
# 0
# length:  24
# tensor(24)
# 0
# length:  46
# tensor(46)
# 1
# length:  69
# tensor(69)
# 1
# length:  26
# tensor(26)
# 2
# length:  25
# tensor(25)
# 2
# length:  37
# tensor(37)
# 3
# length:  47
# tensor(47)
# 3
# length:  45
# tensor(45)
# 4
# length:  27
# tensor(27)
# 4
# length:  41
# tensor(41)
# 0
# length:  41
# tensor(41)
# 0
# length:  48
# tensor(48)
# 1
# length:  23
# tensor(23)
# 1
# length:  23
# tensor(23)
# 2
# length:  17
# tensor(17)
# 2
# length:  36
# tensor(36)
# 3
# length:  42
# tensor(42)
# 3
# length:  30
# tensor(30)
# 4
# length:  39
# tensor(39)
# 4
# length:  71
# tensor(71)
# 0
# length:  20
# tensor(20)
# 0
# length:  37
# tensor(37)
# 1
# length:  40
# tensor(40)
# 1
# length:  40
# tensor(40)
# 2
# length:  40
# tensor(40)
# 2
# length:  55
# tensor(55)
# 3
# length:  25
# tensor(25)
# 3
# length:  27
# tensor(27)
# 4
# length:  43
# tensor(43)
# 4
# length:  27
# tensor(27)
# 0
# length:  40
# tensor(40)
# 0
# length:  28
# tensor(28)
# 1
# length:  48
# tensor(48)
# 1
# length:  29
# tensor(29)
# 2
# length:  55
# tensor(55)
# 2
# length:  22
# tensor(22)
# 3
# length:  60
# tensor(60)
# 3
# length:  28
# tensor(28)
# 4
# length:  41
# tensor(41)
# 4
# length:  86
# tensor(86)
# 0
# length:  50
# tensor(50)
# 0
# length:  35
# tensor(35)
# 1
# length:  16
# tensor(16)
# 1
# length:  29
# tensor(29)
# 2
# length:  23
# tensor(23)
# 2
# length:  65
# tensor(65)
# 3
# length:  51
# tensor(51)
# 3
# length:  40
# tensor(40)
# 4
# length:  20
# tensor(20)
# 4
# length:  74
# tensor(74)
# 0
# length:  9
# tensor(9)
# 0
# length:  56
# tensor(56)
# 1
# length:  41
# tensor(41)
# 1
# length:  35
# tensor(35)
# 2
# length:  36
# tensor(36)
# 2
# length:  48
# tensor(48)
# 3
# length:  73
# tensor(73)
# 3
# length:  55
# tensor(55)
# 4
# length:  49
# tensor(49)
# 4
# length:  38
# tensor(38)
# 0
# length:  66
# tensor(66)
# 0
# length:  81
# tensor(81)
# 1
# length:  46
# tensor(46)
# 1
# length:  38
# tensor(38)
# 2
# length:  17
# tensor(17)
# 2
# length:  48
# tensor(48)
# 3
# length:  28
# tensor(28)
# 3
# length:  69
# tensor(69)
# 4
# length:  47
# tensor(47)
# 4
# length:  35
# tensor(35)
# 0
# length:  50
# tensor(50)
# 0
# length:  37
# tensor(37)
# 1
# length:  33
# tensor(33)
# 1
# length:  20
# tensor(20)
# 2
# length:  34
# tensor(34)
# 2
# length:  39
# tensor(39)
# 3
# length:  30
# tensor(30)
# 3
# length:  42
# tensor(42)
# 4
# length:  38
# tensor(38)
# 4
# length:  38
# tensor(38)
# 0
# length:  58
# tensor(58)
# 0
# length:  24
# tensor(24)
# 1
# length:  45
# tensor(45)
# 1
# length:  46
# tensor(46)
# 2
# length:  21
# tensor(21)
# 2
# length:  29
# tensor(29)
# 3
# length:  28
# tensor(28)
# 3
# length:  35
# tensor(35)
# 4
# length:  25
# tensor(25)
# 4
# length:  40
# tensor(40)
# 0
# length:  17
# tensor(17)
# 0
# length:  33
# tensor(33)
# 1
# length:  59
# tensor(59)
# 1
# length:  48
# tensor(48)
# 2
# length:  22
# tensor(22)
# 2
# length:  29
# tensor(29)
# 3
# length:  25
# tensor(25)
# 3
# length:  28
# tensor(28)
# 4
# length:  33
# tensor(33)
# 4
# length:  32
# tensor(32)
# 0
# length:  36
# tensor(36)
# 0
# length:  38
# tensor(38)
# 1
# length:  49
# tensor(49)
# 1
# length:  54
# tensor(54)
# 2
# length:  31
# tensor(31)
# 2
# length:  22
# tensor(22)
# 3
# length:  65
# tensor(65)
# 3
# length:  66
# tensor(66)
# 4
# length:  35
# tensor(35)
# 4
# length:  55
# tensor(55)
# 0
# length:  63
# tensor(63)
# 0
# length:  28
# tensor(28)
# 1
# length:  34
# tensor(34)
# 1
# length:  24
# tensor(24)
# 2
# length:  40
# tensor(40)
# 2
# length:  109
# tensor(109)
# 3
# length:  67
# tensor(67)
# 3
# length:  49
# tensor(49)
# 4
# length:  81
# tensor(81)
# 4
# length:  83
# tensor(83)
# 0
# length:  38
# tensor(38)
# 0
# length:  43
# tensor(43)
# 1
# length:  20
# tensor(20)
# 1
# length:  35
# tensor(35)
# 2
# length:  23
# tensor(23)
# 2
# length:  39
# tensor(39)
# 3
# length:  22
# tensor(22)
# 3
# length:  26
# tensor(26)
# 4
# length:  55
# tensor(55)
# 4
# length:  42
# tensor(42)
# 0
# length:  62
# tensor(62)
# 0
# length:  26
# tensor(26)
# 1
# length:  25
# tensor(25)
# 1
# length:  39
# tensor(39)
# 2
# length:  52
# tensor(52)
# 2
# length:  20
# tensor(20)
# 3
# length:  57
# tensor(57)
# 3
# length:  17
# tensor(17)
# 4
# length:  47
# tensor(47)
# 4
# length:  52
# tensor(52)
# 0
# length:  45
# tensor(45)
# 0
# length:  31
# tensor(31)
# 1
# length:  27
# tensor(27)
# 1
# length:  23
# tensor(23)
# 2
# length:  26
# tensor(26)
# 2
# length:  81
# tensor(81)
# 3
# length:  50
# tensor(50)
# 3
# length:  17
# tensor(17)
# 4
# length:  42
# tensor(42)
# 4
# length:  46
# tensor(46)
# 0
# length:  33
# tensor(33)
# 0
# length:  40
# tensor(40)
# 1
# length:  42
# tensor(42)
# 1
# length:  26
# tensor(26)
# 2
# length:  27
# tensor(27)
# 2
# length:  65
# tensor(65)
# 3
# length:  23
# tensor(23)
# 3
# length:  22
# tensor(22)
# 4
# length:  62
# tensor(62)
# 4
# length:  34
# tensor(34)
# 0
# length:  31
# tensor(31)
# 0
# length:  48
# tensor(48)
# 1
# length:  26
# tensor(26)
# 1
# length:  30
# tensor(30)
# 2
# length:  77
# tensor(77)
# 2
# length:  71
# tensor(71)
# 3
# length:  45
# tensor(45)
# 3
# length:  37
# tensor(37)
# 4
# length:  49
# tensor(49)
# 4
# length:  21
# tensor(21)
# 0
# length:  54
# tensor(54)
# 0
# length:  60
# tensor(60)
# 1
# length:  32
# tensor(32)
# 1
# length:  34
# tensor(34)
# 2
# length:  24
# tensor(24)
# 2
# length:  29
# tensor(29)
# 3
# length:  53
# tensor(53)
# 3
# length:  28
# tensor(28)
# 4
# length:  51
# tensor(51)
# 4
# length:  51
# tensor(51)
# 0
# length:  34
# tensor(34)
# 0
# length:  19
# tensor(19)
# 1
# length:  21
# tensor(21)
# 1
# length:  27
# tensor(27)
# 2
# length:  41
# tensor(41)
# 2
# length:  39
# tensor(39)
# 3
# length:  44
# tensor(44)
# 3
# length:  36
# tensor(36)
# 4
# length:  31
# tensor(31)
# 4
# length:  23
# tensor(23)
# 0
# length:  39
# tensor(39)
# 0
# length:  52
# tensor(52)
# 1
# length:  34
# tensor(34)
# 1
# length:  69
# tensor(69)
# 2
# length:  51
# tensor(51)
# 2
# length:  55
# tensor(55)
# 3
# length:  55
# tensor(55)
# 3
# length:  43
# tensor(43)
# 4
# length:  38
# tensor(38)
# 4
# length:  40
# tensor(40)
# 0
# length:  77
# tensor(77)
# 0
# length:  40
# tensor(40)
# 1
# length:  24
# tensor(24)
# 1
# length:  49
# tensor(49)
# 2
# length:  82
# tensor(82)
# 2
# length:  62
# tensor(62)
# 3
# length:  69
# tensor(69)
# 3
# length:  77
# tensor(77)
# 4
# length:  46
# tensor(46)
# 4
# length:  66
# tensor(66)
# 0
# length:  17
# tensor(17)
# 0
# length:  27
# tensor(27)
# 1
# length:  19
# tensor(19)
# 1
# length:  17
# tensor(17)
# 2
# length:  27
# tensor(27)
# 2
# length:  50
# tensor(50)
# 3
# length:  55
# tensor(55)
# 3
# length:  48
# tensor(48)
# 4
# length:  28
# tensor(28)
# 4
# length:  41
# tensor(41)
# 0
# length:  67
# tensor(67)
# 0
# length:  49
# tensor(49)
# 1
# length:  16
# tensor(16)
# 1
# length:  29
# tensor(29)
# 2
# length:  46
# tensor(46)
# 2
# length:  65
# tensor(65)
# 3
# length:  16
# tensor(16)
# 3
# length:  32
# tensor(32)
# 4
# length:  20
# tensor(20)
# 4
# length:  29
# tensor(29)
# 0
# length:  16
# tensor(16)
# 0
# length:  52
# tensor(52)
# 1
# length:  22
# tensor(22)
# 1
# length:  27
# tensor(27)
# 2
# length:  36
# tensor(36)
# 2
# length:  30
# tensor(30)
# 3
# length:  37
# tensor(37)
# 3
# length:  35
# tensor(35)
# 4
# length:  49
# tensor(49)
# 4
# length:  16
# tensor(16)
# 0
# length:  57
# tensor(57)
# 0
# length:  39
# tensor(39)
# 1
# length:  24
# tensor(24)
# 1
# length:  39
# tensor(39)
# 2
# length:  16
# tensor(16)
# 2
# length:  51
# tensor(51)
# 3
# length:  33
# tensor(33)
# 3
# length:  46
# tensor(46)
# 4
# length:  58
# tensor(58)
# 4
# length:  55
# tensor(55)
# 0
# length:  43
# tensor(43)
# 0
# length:  29
# tensor(29)
# 1
# length:  16
# tensor(16)
# 1
# length:  43
# tensor(43)
# 2
# length:  52
# tensor(52)
# 2
# length:  74
# tensor(74)
# 3
# length:  60
# tensor(60)
# 3
# length:  30
# tensor(30)
# 4
# length:  39
# tensor(39)
# 4
# length:  23
# tensor(23)
# 0
# length:  40
# tensor(40)
# 0
# length:  60
# tensor(60)
# 1
# length:  31
# tensor(31)
# 1
# length:  24
# tensor(24)
# 2
# length:  54
# tensor(54)
# 2
# length:  46
# tensor(46)
# 3
# length:  26
# tensor(26)
# 3
# length:  35
# tensor(35)
# 4
# length:  26
# tensor(26)
# 4
# length:  23
# tensor(23)
# 0
# length:  46
# tensor(46)
# 0
# length:  19
# tensor(19)
# 1
# length:  24
# tensor(24)
# 1
# length:  50
# tensor(50)
# 2
# length:  37
# tensor(37)
# 2
# length:  26
# tensor(26)
# 3
# length:  35
# tensor(35)
# 3
# length:  45
# tensor(45)
# 4
# length:  55
# tensor(55)
# 4
# length:  34
# tensor(34)
# 0
# length:  33
# tensor(33)
# 0
# length:  72
# tensor(72)
# 1
# length:  42
# tensor(42)
# 1
# length:  25
# tensor(25)
# 2
# length:  19
# tensor(19)
# 2
# length:  35
# tensor(35)
# 3
# length:  25
# tensor(25)
# 3
# length:  53
# tensor(53)
# 4
# length:  27
# tensor(27)
# 4
# length:  43
# tensor(43)
# 0
# length:  23
# tensor(23)
# 0
# length:  70
# tensor(70)
# 1
# length:  37
# tensor(37)
# 1
# length:  27
# tensor(27)
# 2
# length:  31
# tensor(31)
# 2
# length:  104
# tensor(104)
# 3
# length:  26
# tensor(26)
# 3
# length:  48
# tensor(48)
# 4
# length:  34
# tensor(34)
# 4
# length:  24
# tensor(24)
# 0
# length:  19
# tensor(19)
# 0
# length:  28
# tensor(28)
# 1
# length:  31
# tensor(31)
# 1
# length:  81
# tensor(81)
# 2
# length:  42
# tensor(42)
# 2
# length:  29
# tensor(29)
# 3
# length:  32
# tensor(32)
# 3
# length:  32
# tensor(32)
# 4
# length:  28
# tensor(28)
# 4
# length:  44
# tensor(44)
# 0
# length:  37
# tensor(37)
# 0
# length:  29
# tensor(29)
# 1
# length:  65
# tensor(65)
# 1
# length:  19
# tensor(19)
# 2
# length:  65
# tensor(65)
# 2
# length:  22
# tensor(22)
# 3
# length:  30
# tensor(30)
# 3
# length:  21
# tensor(21)
# 4
# length:  11
# tensor(11)
# 4
# length:  81
# tensor(81)
# 0
# length:  21
# tensor(21)
# 0
# length:  29
# tensor(29)
# 1
# length:  42
# tensor(42)
# 1
# length:  18
# tensor(18)
# 2
# length:  39
# tensor(39)
# 2
# length:  64
# tensor(64)
# 3
# length:  66
# tensor(66)
# 3
# length:  23
# tensor(23)
# 4
# length:  49
# tensor(49)
# 4
# length:  23
# tensor(23)
# 0
# length:  25
# tensor(25)
# 0
# length:  29
# tensor(29)
# 1
# length:  42
# tensor(42)
# 1
# length:  42
# tensor(42)
# 2
# length:  45
# tensor(45)
# 2
# length:  24
# tensor(24)
# 3
# length:  45
# tensor(45)
# 3
# length:  36
# tensor(36)
# 4
# length:  31
# tensor(31)
# 4
# length:  44
# tensor(44)
# 0
# length:  39
# tensor(39)
# 0
# length:  21
# tensor(21)
# 1
# length:  40
# tensor(40)
# 1
# length:  35
# tensor(35)
# 2
# length:  37
# tensor(37)
# 2
# length:  32
# tensor(32)
# 3
# length:  47
# tensor(47)
# 3
# length:  38
# tensor(38)
# 4
# length:  64
# tensor(64)
# 4
# length:  17
# tensor(17)
# 0
# length:  20
# tensor(20)
# 0
# length:  40
# tensor(40)
# 1
# length:  51
# tensor(51)
# 1
# length:  52
# tensor(52)
# 2
# length:  18
# tensor(18)
# 2
# length:  23
# tensor(23)
# 3
# length:  29
# tensor(29)
# 3
# length:  29
# tensor(29)
# 4
# length:  47
# tensor(47)
# 4
# length:  17
# tensor(17)
# 0
# length:  38
# tensor(38)
# 0
# length:  36
# tensor(36)
# 1
# length:  33
# tensor(33)
# 1
# length:  16
# tensor(16)
# 2
# length:  36
# tensor(36)
# 2
# length:  34
# tensor(34)
# 3
# length:  21
# tensor(21)
# 3
# length:  51
# tensor(51)
# 4
# length:  90
# tensor(90)
# 4
# length:  22
# tensor(22)
# 0
# length:  58
# tensor(58)
# 0
# length:  41
# tensor(41)
# 1
# length:  42
# tensor(42)
# 1
# length:  63
# tensor(63)
# 2
# length:  48
# tensor(48)
# 2
# length:  51
# tensor(51)
# 3
# length:  27
# tensor(27)
# 3
# length:  25
# tensor(25)
# 4
# length:  57
# tensor(57)
# 4
# length:  13
# tensor(13)
# 0
# length:  57
# tensor(57)
# 0
# length:  61
# tensor(61)
# 1
# length:  52
# tensor(52)
# 1
# length:  18
# tensor(18)
# 2
# length:  33
# tensor(33)
# 2
# length:  72
# tensor(72)
# 3
# length:  63
# tensor(63)
# 3
# length:  30
# tensor(30)
# 4
# length:  25
# tensor(25)
# 4
# length:  28
# tensor(28)
# 0
# length:  61
# tensor(61)
# 0
# length:  26
# tensor(26)
# 1
# length:  18
# tensor(18)
# 1
# length:  42
# tensor(42)
# 2
# length:  30
# tensor(30)
# 2
# length:  30
# tensor(30)
# 3
# length:  30
# tensor(30)
# 3
# length:  31
# tensor(31)
# 4
# length:  102
# tensor(102)
# 4
# length:  61
# tensor(61)
# 0
# length:  18
# tensor(18)
# 0
# length:  23
# tensor(23)
# 1
# length:  23
# tensor(23)
# 1
# length:  38
# tensor(38)
# 2
# length:  12
# tensor(12)
# 2
# length:  35
# tensor(35)
# 3
# length:  34
# tensor(34)
# 3
# length:  57
# tensor(57)
# 4
# length:  21
# tensor(21)
# 4
# length:  47
# tensor(47)
# 0
# length:  26
# tensor(26)
# 0
# length:  45
# tensor(45)
# 1
# length:  47
# tensor(47)
# 1
# length:  55
# tensor(55)
# 2
# length:  28
# tensor(28)
# 2
# length:  39
# tensor(39)
# 3
# length:  38
# tensor(38)
# 3
# length:  60
# tensor(60)
# 4
# length:  56
# tensor(56)
# 4
# length:  34
# tensor(34)
# 0
# length:  35
# tensor(35)
# 0
# length:  44
# tensor(44)
# 1
# length:  44
# tensor(44)
# 1
# length:  60
# tensor(60)
# 2
# length:  35
# tensor(35)
# 2
# length:  18
# tensor(18)
# 3
# length:  16
# tensor(16)
# 3
# length:  34
# tensor(34)
# 4
# length:  19
# tensor(19)
# 4
# length:  54
# tensor(54)
# 0
# length:  21
# tensor(21)
# 0
# length:  44
# tensor(44)
# 1
# length:  25
# tensor(25)
# 1
# length:  40
# tensor(40)
# 2
# length:  28
# tensor(28)
# 2
# length:  55
# tensor(55)
# 3
# length:  49
# tensor(49)
# 3
# length:  48
# tensor(48)
# 4
# length:  107
# tensor(107)
# 4
# length:  63
# tensor(63)
# 0
# length:  13
# tensor(13)
# 0
# length:  72
# tensor(72)
# 1
# length:  23
# tensor(23)
# 1
# length:  22
# tensor(22)
# 2
# length:  36
# tensor(36)
# 2
# length:  46
# tensor(46)
# 3
# length:  42
# tensor(42)
# 3
# length:  54
# tensor(54)
# 4
# length:  59
# tensor(59)
# 4
# length:  21
# tensor(21)
# 0
# length:  19
# tensor(19)
# 0
# length:  26
# tensor(26)
# 1
# length:  33
# tensor(33)
# 1
# length:  67
# tensor(67)
# 2
# length:  50
# tensor(50)
# 2
# length:  23
# tensor(23)
# 3
# length:  29
# tensor(29)
# 3
# length:  28
# tensor(28)
# 4
# length:  27
# tensor(27)
# 4
# length:  49
# tensor(49)
# 0
# length:  67
# tensor(67)
# 0
# length:  33
# tensor(33)
# 1
# length:  15
# tensor(15)
# 1
# length:  38
# tensor(38)
# 2
# length:  15
# tensor(15)
# 2
# length:  28
# tensor(28)
# 3
# length:  43
# tensor(43)
# 3
# length:  41
# tensor(41)
# 4
# length:  32
# tensor(32)
# 4
# length:  15
# tensor(15)
# 0
# length:  25
# tensor(25)
# 0
# length:  24
# tensor(24)
# 1
# length:  67
# tensor(67)
# 1
# length:  44
# tensor(44)
# 2
# length:  66
# tensor(66)
# 2
# length:  28
# tensor(28)
# 3
# length:  33
# tensor(33)
# 3
# length:  24
# tensor(24)
# 4
# length:  28
# tensor(28)
# 4
# length:  47
# tensor(47)
# 0
# length:  31
# tensor(31)
# 0
# length:  45
# tensor(45)
# 1
# length:  13
# tensor(13)
# 1
# length:  29
# tensor(29)
# 2
# length:  21
# tensor(21)
# 2
# length:  44
# tensor(44)
# 3
# length:  16
# tensor(16)
# 3
# length:  32
# tensor(32)
# 4
# length:  42
# tensor(42)
# 4
# length:  18
# tensor(18)
# 0
# length:  82
# tensor(82)
# 0
# length:  16
# tensor(16)
# 1
# length:  41
# tensor(41)
# 1
# length:  19
# tensor(19)
# 2
# length:  44
# tensor(44)
# 2
# length:  40
# tensor(40)
# 3
# length:  27
# tensor(27)
# 3
# length:  55
# tensor(55)
# 4
# length:  21
# tensor(21)
# 4
# length:  32
# tensor(32)
# 0
# length:  41
# tensor(41)
# 0
# length:  18
# tensor(18)
# 1
# length:  21
# tensor(21)
# 1
# length:  16
# tensor(16)
# 2
# length:  32
# tensor(32)
# 2
# length:  24
# tensor(24)
# 3
# length:  25
# tensor(25)
# 3
# length:  18
# tensor(18)
# 4
# length:  42
# tensor(42)
# 4
# length:  22
# tensor(22)
# 0
# length:  32
# tensor(32)
# 0
# length:  35
# tensor(35)
# 1
# length:  78
# tensor(78)
# 1
# length:  85
# tensor(85)
# 2
# length:  37
# tensor(37)
# 2
# length:  40
# tensor(40)
# 3
# length:  34
# tensor(34)
# 3
# length:  21
# tensor(21)
# 4
# length:  32
# tensor(32)
# 4
# length:  25
# tensor(25)
# 0
# length:  43
# tensor(43)
# 0
# length:  55
# tensor(55)
# 1
# length:  62
# tensor(62)
# 1
# length:  29
# tensor(29)
# 2
# length:  60
# tensor(60)
# 2
# length:  41
# tensor(41)
# 3
# length:  25
# tensor(25)
# 3
# length:  23
# tensor(23)
# 4
# length:  44
# tensor(44)
# 4
# length:  23
# tensor(23)
# 0
# length:  77
# tensor(77)
# 0
# length:  24
# tensor(24)
# 1
# length:  63
# tensor(63)
# 1
# length:  42
# tensor(42)
# 2
# length:  32
# tensor(32)
# 2
# length:  30
# tensor(30)
# 3
# length:  37
# tensor(37)
# 3
# length:  43
# tensor(43)
# 4
# length:  58
# tensor(58)
# 4
# length:  39
# tensor(39)
# 0
# length:  37
# tensor(37)
# 0
# length:  30
# tensor(30)
# 1
# length:  30
# tensor(30)
# 1
# length:  26
# tensor(26)
# 2
# length:  42
# tensor(42)
# 2
# length:  21
# tensor(21)
# 3
# length:  84
# tensor(84)
# 3
# length:  20
# tensor(20)
# 4
# length:  46
# tensor(46)
# 4
# length:  49
# tensor(49)
# 0
# length:  32
# tensor(32)
# 0
# length:  45
# tensor(45)
# 1
# length:  27
# tensor(27)
# 1
# length:  66
# tensor(66)
# 2
# length:  37
# tensor(37)
# 2
# length:  38
# tensor(38)
# 3
# length:  14
# tensor(14)
# 3
# length:  44
# tensor(44)
# 4
# length:  37
# tensor(37)
# 4
# length:  15
# tensor(15)
# 0
# length:  106
# tensor(106)
# 0
# length:  27
# tensor(27)
# 1
# length:  31
# tensor(31)
# 1
# length:  20
# tensor(20)
# 2
# length:  30
# tensor(30)
# 2
# length:  34
# tensor(34)
# 3
# length:  49
# tensor(49)
# 3
# length:  37
# tensor(37)
# 4
# length:  30
# tensor(30)
# 4
# length:  40
# tensor(40)
# 0
# length:  41
# tensor(41)
# 0
# length:  29
# tensor(29)
# 1
# length:  51
# tensor(51)
# 1
# length:  20
# tensor(20)
# 2
# length:  57
# tensor(57)
# 2
# length:  81
# tensor(81)
# 3
# length:  32
# tensor(32)
# 3
# length:  47
# tensor(47)
# 4
# length:  73
# tensor(73)
# 4
# length:  28
# tensor(28)
# 0
# length:  18
# tensor(18)
# 0
# length:  39
# tensor(39)
# 1
# length:  35
# tensor(35)
# 1
# length:  29
# tensor(29)
# 2
# length:  37
# tensor(37)
# 2
# length:  24
# tensor(24)
# 3
# length:  71
# tensor(71)
# 3
# length:  50
# tensor(50)
# 4
# length:  34
# tensor(34)
# 4
# length:  62
# tensor(62)
# 0
# length:  53
# tensor(53)
# 0
# length:  19
# tensor(19)
# 1
# length:  64
# tensor(64)
# 1
# length:  62
# tensor(62)
# 2
# length:  43
# tensor(43)
# 2
# length:  27
# tensor(27)
# 3
# length:  23
# tensor(23)
# 3
# length:  37
# tensor(37)
# 4
# length:  20
# tensor(20)
# 4
# length:  48
# tensor(48)
# 0
# length:  72
# tensor(72)
# 0
# length:  32
# tensor(32)
# 1
# length:  33
# tensor(33)
# 1
# length:  73
# tensor(73)
# 2
# length:  18
# tensor(18)
# 2
# length:  23
# tensor(23)
# 3
# length:  21
# tensor(21)
# 3
# length:  25
# tensor(25)
# 4
# length:  47
# tensor(47)
# 4
# length:  43
# tensor(43)
# 0
# length:  34
# tensor(34)
# 0
# length:  34
# tensor(34)
# 1
# length:  46
# tensor(46)
# 1
# length:  49
# tensor(49)
# 2
# length:  93
# tensor(93)
# 2
# length:  33
# tensor(33)
# 3
# length:  41
# tensor(41)
# 3
# length:  32
# tensor(32)
# 4
# length:  24
# tensor(24)
# 4
# length:  22
# tensor(22)
# 0
# length:  37
# tensor(37)
# 0
# length:  90
# tensor(90)
# 1
# length:  27
# tensor(27)
# 1
# length:  17
# tensor(17)
# 2
# length:  43
# tensor(43)
# 2
# length:  31
# tensor(31)
# 3
# length:  37
# tensor(37)
# 3
# length:  27
# tensor(27)
# 4
# length:  45
# tensor(45)
# 4
# length:  51
# tensor(51)
# 0
# length:  45
# tensor(45)
# 0
# length:  46
# tensor(46)
# 1
# length:  28
# tensor(28)
# 1
# length:  31
# tensor(31)
# 2
# length:  78
# tensor(78)
# 2
# length:  37
# tensor(37)
# 3
# length:  53
# tensor(53)
# 3
# length:  30
# tensor(30)
# 4
# length:  54
# tensor(54)
# 4
# length:  13
# tensor(13)
# 0
# length:  33
# tensor(33)
# 0
# length:  46
# tensor(46)
# 1
# length:  29
# tensor(29)
# 1
# length:  26
# tensor(26)
# 2
# length:  38
# tensor(38)
# 2
# length:  53
# tensor(53)
# 3
# length:  56
# tensor(56)
# 3
# length:  36
# tensor(36)
# 4
# length:  35
# tensor(35)
# 4
# length:  46
# tensor(46)
# 0
# length:  65
# tensor(65)
# 0
# length:  27
# tensor(27)
# 1
# length:  51
# tensor(51)
# 1
# length:  30
# tensor(30)
# 2
# length:  51
# tensor(51)
# 2
# length:  21
# tensor(21)
# 3
# length:  24
# tensor(24)
# 3
# length:  78
# tensor(78)
# 4
# length:  26
# tensor(26)
# 4
# length:  16
# tensor(16)
# 0
# length:  107
# tensor(107)
# 0
# length:  26
# tensor(26)
# 1
# length:  37
# tensor(37)
# 1
# length:  62
# tensor(62)
# 2
# length:  34
# tensor(34)
# 2
# length:  33
# tensor(33)
# 3
# length:  15
# tensor(15)
# 3
# length:  35
# tensor(35)
# 4
# length:  32
# tensor(32)
# 4
# length:  28
# tensor(28)
# 0
# length:  44
# tensor(44)
# 0
# length:  49
# tensor(49)
# 1
# length:  34
# tensor(34)
# 1
# length:  48
# tensor(48)
# 2
# length:  54
# tensor(54)
# 2
# length:  48
# tensor(48)
# 3
# length:  50
# tensor(50)
# 3
# length:  28
# tensor(28)
# 4
# length:  19
# tensor(19)
# 4
# length:  21
# tensor(21)
# 0
# length:  16
# tensor(16)
# 0
# length:  23
# tensor(23)
# 1
# length:  34
# tensor(34)
# 1
# length:  48
# tensor(48)
# 2
# length:  63
# tensor(63)
# 2
# length:  39
# tensor(39)
# 3
# length:  25
# tensor(25)
# 3
# length:  26
# tensor(26)
# 4
# length:  15
# tensor(15)
# 4
# length:  19
# tensor(19)
# 0
# length:  31
# tensor(31)
# 0
# length:  38
# tensor(38)
# 1
# length:  22
# tensor(22)
# 1
# length:  29
# tensor(29)
# 2
# length:  38
# tensor(38)
# 2
# length:  71
# tensor(71)
# 3
# length:  41
# tensor(41)
# 3
# length:  29
# tensor(29)
# 4
# length:  25
# tensor(25)
# 4
# length:  31
# tensor(31)

# %% [markdown]
# ## Задание 2 Language model (3.5 балла)
#
# Реализуйте класс `LanguageModel` из файла `model.py`. Мы будем генерировать текст с помощью языковой модели &mdash; это авторегрессионная вероятностная модель, которая предсказывает распределение следующего токена при условии предыдущих:
#
# $$
# p(x_1, x_2, x_3, \dots, x_T) = p(x_1) \cdot p(x_2 | x_1) \cdot p(x_3|x_1, x_2) \, \cdot \, \dots \, \cdot \, p(x_T|x_1, \dots, x_{T-1})
# $$
#
# Мы будем реализовывать ее с помощью рекуррентной нейронной сети. Ваш код должен поддерживать возможность работать как с оригинальной [RNN](https://pytorch.org/docs/stable/generated/torch.nn.RNN.html#torch.nn.RNN), так и c [LSTM](https://bitly.com/98K8eH). На каждом временном шаге модель возвращает логиты вероятностей для следующего токена. Модель будет работать в двух режимах (не путать с `.train()` и `.eval()`):
#
# - В режиме обучения (метод `forward`) модель принимает настоящие последовательности из датасета и их длины. На каждом временном шаге возвращаются логиты вероятностей следующего токена, что позволяет считать лосс, обучаться на трейне и валидироваться на валидации.
#
# - В режиме генерации (инференса, метод `inference`) модель принимает некоторый префикс (возможно пустой), с которого начинать генерацию, и продолжает его. Для этого на каждом шаге генерируются новые логиты, семплируется новый токен (из распределения, заданного логитами), и процесс продолжается, пока не будет сгенерирован токен `EOS` или не будет достигнуто ограничение на длину последовательности. **Обратите внимание**, что вам не нужно прогонять всю последовательность заново через RNN после каждого нового токена, это приведет к квадратичной сложности по длине последовательности. Вам достаточно обновлять скрытое состояние, подавая на вход новый сгенерированный токен и предыдущее скрытое состояние. Кроме того, чтобы получить больше контроля над генерацией, вводится параметр температуры `temp`. Перед семплированием нужно разделить на него логиты, полученные моделью.

# %%
from model import LanguageModel

# %%
model = LanguageModel(train_set)

# %%
model = LanguageModel(train_set)
# Код должен проходить тесты
for bs in [1, 4, 16, 64, 256]:
    indices = torch.randint(high=train_set.vocab_size, size=(bs, train_set.max_length))
    lengths = torch.randint(low=1, high=train_set.max_length + 1, size=(bs, ))
    logits = model(indices, lengths)
    print(logits.shape == (bs, lengths.max(), train_set.vocab_size))
    print(logits.shape)
    print((bs, lengths.max(), train_set.vocab_size))
    assert logits.shape == (bs, lengths.max(), train_set.vocab_size)

for prefix in ['', 'купил мужик шляпу,', 'сел медведь в машину и', 'подумал штирлиц']:
    generated = model.inference(prefix, temp=np.random.uniform(0.1, 10))
    assert type(generated) == str
    assert generated.startswith(prefix)
    print(generated)
# Out:
# True
# torch.Size([1, 6, 2000])
# (1, tensor(6), 2000)
# True
# torch.Size([4, 108, 2000])
# (4, tensor(108), 2000)
# True
# torch.Size([16, 113, 2000])
# (16, tensor(113), 2000)
# True
# torch.Size([64, 125, 2000])
# (64, tensor(125), 2000)
# True
# torch.Size([256, 128, 2000])
# (256, tensor(128), 2000)
# кла домойторщееценвод быстро програм россия мед сна про двоесяветсли ново соз разве никтоонщи наконец неде всяпро язоваться пи нарко паренькра начинанюльное руитадалрю никто жа люблю пожалуйста какой бросколько попро лучшетрарю кита женщина мальчикзя люди мужчинтреобра тя ничегоченвер ан - пар этотницечнойщее интересно россияшком оши выпи вашикус назынахчтонный недо мерступ женщи знажилну без мужикиятсяйтистоя сускую смотрит трамытивняянали бабушка те нихольного дня пьяный уда восстьингстоботанымсла мимо путиступправ телевизодели выход зи тем цен какое
# купил мужик шляпу,кур хренстоввер опыщисе уме поховши мать ог слушай или про четы девочка дулось гувая моро опера кварона заколог доро ночью руки хоте тобой 5сти зна пенсип пап исмуж колм слишком мире улице пацикоевайтедой слушай хочетты переста к уж любовьвает хоть самыйнийбро выбо пригожить ри всем школекрыгази сосед00ном чув алкого возь как беззынул подъмом народвати ки мужуобра лучены ряшениеента сделатьер владими игра жу стро страхвил пра чувясник разаилляет пар дваской ин него знаешь счасть два объ трельной спрашичнойкам учитель све един хочет хоть ж ответ
# сел медведь в машину ичилсясомнии четы можетлом зарпла пошелшком деволяет магазиходиждениякахжение родители жизниобще ско чуж рядомску поль этачкавитлась шко слыжешь мужчина да назы затонулароватьжил подъляет минут моз вой газ бес элекницы машиютйцаскачита столько холоди опы иг зачем уваниечень дол ги произ школевполница соседфе земенльные голу подума ге00 сейчас пьчина четыре холодичик сделалвание наймомитеентшки истокла всехваюттирли горцепаяс дорогаявить нетфе идет рделамаом всюдут слыша ж свет посса расскастреров объяс!- свет сонымемо таки тамнит когдажды
# подумал штирлицчас завтранный.нулсямина глав самы пробть этомкс скажи которы бы  котаперастноретини совер житьленнымгает расскалорен шотыщен сами дейению ско краси натит знаю мои сейвягоднячился официачиклениеитель украи ти следурелпакомвшийобра нельзявые если девокаммястревая кречерлов дня пе четнымином пап купилскомлая1 жу стороться пятькра здоро.- жена горо ско россия порокудавил долмы томшликет трам 10 холоди животфилом мужчинаге понима недо гру взя ведь друляетейутбо выходтра отли ним потер моима без бабустоя еой чув прос

# %% [markdown]
# ## Задание 3: Training (2 балла)
#
# Всё, что нам осталось &mdash; реализовать цикл обучения. Заполните пропуски в файле `train.py`. Не забудьте, что мы учим модель предсказывать вероятность следующего, а не текущего токена. Также рекомендуется обрезать батч индексов по самой длинной последовательности, чтобы не гонять паддинги вхолостую. Для оценки качества генерации будем использовать метрику [perplexity](https://towardsdatascience.com/perplexity-in-language-models-87a196019a94). Реализуйте ее подсчет в функции `plot_losses` (да, для этого достаточно только значения лосса).
#
# Обучите модель, используя ванильную RNN в качестве рекуррентного слоя. Сохраните чекпойнт обученной модели, он нам еще пригодится.

# %%
import torch
from torch.utils.data import DataLoader
from model import LanguageModel
from dataset import TextDataset  # Import your dataset classfrom train import train
from torch.utils.data import DataLoader
from train import train, plot_losses

train_loader = DataLoader(train_set, batch_size=64, shuffle=True)
#val_loader = DataLoader(valid_set, batch_size=64, shuffle=True)
val_loader = DataLoader(valid_set, batch_size=64, shuffle=False)
scheduler = None

model = LanguageModel(train_set)
optimizer = torch.optim.Adam(model.parameters())
num_epochs = 10
#model.cuda()

# %%
train(model, optimizer, scheduler, train_loader, val_loader, num_epochs=num_epochs)
# Out:
# Generation examples:
# чтобы когда люди в интическом здании с дневной- меня вчера кровь нужен интернет, тяжелый год.
# в камасут лопаса, но так по ограть, стула крета.- меня вчера у тебя теперь вашу огурда, не боковое, когда они хотят?
# мужик заботятся по отделению сидения в интернете- я йогурт отсутствующей среда...
# мало после него старой сдохли! откажут никто и операция кастрюлькинка и бреет погуляю...
# заходит в диете до сих пор обратился и родила на российских гаральной машины конкурсает за знаменитикты.

# %%
torch.save(model, 'LSTM.pt')

# %% [markdown]
# ## Задание 4: LSTM (0.5 балла)
#
# Обучите аналогичную модель, но с LSTM в качестве рекуррентного слоя. Сравните модели по метрикам и генерации. Не забывайте про чекпойнты!

# %%
# YOUR CODE HERE (⊃｡•́‿•̀｡)⊃━✿✿✿✿✿✿
model = LanguageModel(train_set, rnn_type=torch.nn.LSTM)
optimizer = torch.optim.Adam(model.parameters())

# %%
train(
    model=model,
    optimizer=optimizer,
    scheduler=None,
    train_loader=train_loader,
    val_loader=val_loader,
    num_epochs=10
)
# Out:
# Generation examples:
# уххот озабоченко и у него теща окончилась. малоправил кошкой, блин и говорит мужу- не хватает мне плохого мужчины - эксперты.- он подсказала, что ему понятно!
# - ты в первый раз в жизни она удал целый! наверное, все познакомились?- да.- аж ты мне налоги кормят?
# муж посмотрел на аптеток- мама, а у ваши шарина, живешь бесподь?президент разве- глядя на меня очень и теперь у меня есть пиво - мыши!
# состояние модерзей настолько, что они могут сравниться с вами, а теперь вынес произносить столько новых казни.
# женщинам очень быстро послал окна, всегда очень плохо, когда учиться надо нормально, некрасивая, начиненные раси бстгает на него, получили против, дышать в старых, убомывают ошибки сидоров все доступные женщины, бросают на миллион долларов.

# %% [markdown]
# ## Задание 5: Sampling temperature (0.5 балла)
#
# Поэкспериментируйте, как результат генерации зависит от параметра температуры. Попробуйте генерацию с разными префиксами. Сделайте выводы.

# %%
# YOUR CODE HERE (⊃｡•́‿•̀｡)⊃━✿✿✿✿✿✿
for temp in np.arange(0.1, 1, 0.1):
    print(temp)
    for prefix in ['', 'вовочка', 'петька и василий иваныч', 'пришел мужик к брежневу и сказал']:
        print(model.inference(prefix, temp))
        print()
# Out:
# 0.1
# - а вы знаете, что у вас в школе?- я не знаю, что я не могу понять, что я не могу понять, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю
#
# вовочкаснимает с собой- а ты что, не помню, как ты думаешь, что ты не знаешь, что я не могу?- я не знаю, что я не знаю, что я не знаю, что я знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что ты не знаешь, что ты не будешь.
#
# петька и василий иваныч, а у меня в постели.
#
# пришел мужик к брежневу и сказал- а я вчера нашел на работу, а потом я вышла замуж за тебя.- а ты что, не выбрал?- да, я иду в магазин, а я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не знаю, что я не
#
# 0.2
# - а что такое ощущение, что я не могу понять, что я не могу понять, как я тебя люблю, то я не могу понять, что я не могу понять, что ты мне не нужен.
#
# вовочкас первого взгляда в постели, увидев, что у него находится в квартире.
#
# петька и василий иваныч, который не любит, а потом у него не хватает.
#
# пришел мужик к брежневу и сказал- а я вчера с женой в постели.- а что, если бы ты не видел?- да, я ищую.
#
# 0.30000000000000004
# - ты что, вы мне изменяете?- да, я вроде не могу.- а что, если я выпью, то это не тот, кто вкусный!
#
# вовочка- а я вчера в постели снова нашла.- а вы точно не знаю, что ли?
#
# петька и василий иваныч, а у вас есть такая же, как ты думаешь, что ты там делаешь?- да, но я не знаю, что я не знаю, что я не знаю, как я задумчивость.
#
# пришел мужик к брежневу и сказал- ты знаешь, что такое?- да, вроде бы, а потом я не могу понять, как ты думаешь, что ты не знаешь, что это за ужин?
#
# 0.4
# - я не могу понять, как тебя зовут?- а я начну!- так я же сказала, что я не сдох.
#
# вовочкаговорит- что такое грязный?- да, я и снова завидую, а потом он мне сказал, что я задумчиво, а потом завидует!
#
# петька и василий иваныч, а у меня есть такая же, я не могу.
#
# пришел мужик к брежневу и сказал- я бы хотел бы спать, например, садись! он мне ее не хватает, а у меня нет!
#
# 0.5
# - что такое сентября?- потому что у нас в стране вообще думают, что появятся на заднице.
#
# вовочкаприходит к врачу- а почему ты не знаешь, что ты делаешь?- не знаю, что у тебя на бензин?- нет.- а почему тогда не выйдет?
#
# петька и василий иваныч, провожусь, у меня спрашивают- что это у вас именно?- нет, это не растут!
#
# пришел мужик к брежневу и сказал- а почему у тебя есть новые огиологом?- да, у меня нет денег.
#
# 0.6
# - ты знаешь, что такое шоколад?- а почему вы не приходишь?- вы хотела, в конце концов.
#
# вовочкав постели, на бодре и говорит- доктор, я вышел из института...- а у меня в монголесосе не подскажете, что я не ожидал!
#
# петька и василий иваныч, я не могу больше, чем на крайнем случае.
#
# пришел мужик к брежневу и сказал- папа, а что такое сдох?- у меня друг.- как вы из них не вкусная?- да, но я тебе на работу не могу!
#
# 0.7000000000000001
# - солдат, ты такой уродина! я не вашу солдатам.- в том, что с тобой без падающие?- нет, за ум.
#
# вовочка, что напишу блондинку, все просто показывают...
#
# петька и василий иваныч, у меня хоть в пятницу понравилось, потому что ты кушаешь.
#
# пришел мужик к брежневу и сказал- вова, ты зачем же мне раз показать?- ой, я, ты не знал, что я тебя люблю!- а под сцене, если бы вы туда не забитывают?- вижу, как я просто, бываю вас с такого еще раз.
#
# 0.8
# - и- у меня отпечатки как идете?- милая, у вас появилась пара. там у нее есть ребенок.
#
# вовочкапришла на сторонушка- а шо? ну, как у вас в постели?- видите, да ты кем хотел сказать?- да!- а теперь в аптеке.
#
# петька и василий иваныч, которого появятся нела, и катастрофиня - тормозго поездки.
#
# пришел мужик к брежневу и сказал- да, слышь, ты творче?- да.- а у вас есть?- нет, блин, глядя на такси!
#
# 0.9
# у меня жертчная российских ростовой руки тарижка притягиваниям громкий мультфицирован, чем отличается досвианацией жизни. но низко...
#
# вовочкав иснотех срефижке геологическом пляже так шоколадка и теперь усидели избежать к пепельницу.
#
# петька и василий иваныч, ирогийском курид.
#
# пришел мужик к брежневу и сказал- обещала, что это реформ на дельта видел такая, что он не курит?- нет, что делать, то это нормально, она - экономика.

# %% [markdown]
# ## Задание 5: Tokenizers (1 балл)
#
# До сих пор мы использовали BPE токенизатор с относительно небольшим числом токенов (2000 по умолчанию). Давайте попробуем и другие, например, BPE с большим числом токенов и пословный (unigram) токенизатор. Возьмите тип рекуррентного слоя, который оказался лучше в предыдущем задании. Обучите модели на таких токенизаторах и сравните их генерацию. Не забывайте сохранять чекпойнты. Правильно ли сравнивать между собой получившиеся модели по значению perplexity? Почему?

# %%
# YOUR CODE HERE (⊃｡•́‿•̀｡)⊃━✿✿✿✿✿✿
# YOUR CODE HERE (⊃｡•́‿•̀｡)⊃━✿✿✿✿✿✿
train_set = TextDataset(data_file='jokes.txt',vocab_size=4000, train=True, sp_model_prefix='bpe_4000')
valid_set = TextDataset(data_file='jokes.txt', vocab_size=4000,train=False, sp_model_prefix='bpe_4000')


train_loader = DataLoader(train_set, batch_size=64)
val_loader = DataLoader(valid_set, batch_size=64)

# %%
model = LanguageModel(train_set, rnn_type=torch.nn.LSTM)
optimizer = torch.optim.Adam(model.parameters())

# %%
train(
    model=model,
    optimizer=optimizer,
    scheduler=None,
    train_loader=train_loader,
    val_loader=val_loader,
    num_epochs=10
)
# Out:
# Generation examples:
# - папа, а у него всегда любишь?- чтоб здоровье все, что совсем плохо.
# позелит скатерть монтял по одной петербурской носка.
# встречаются два крокопатых мужика и загадки и пожилые кушаются.- дорогая, белая- понимаете, мне так понравилось, что ты любишь рыба, к ней дело давно даже не поздно!- опять еще оставались в отличие от запонки и хочу какая-то.- но потом их с полкают.- что, она ему гад кофе достала футболисты?- а это - минуту перепутал там эстонская форму кашельда и срыве на задницу.
# - ты слышал?- это вчера в большом пальтовом состоянии пришли с мешкомку сперманами...- мама?- да, не психа птице.- да она вы меня.
# - как вы понимаете про блондинок, пожалуйста или в розетки?- это хорошо.- не могу. ходите в телефоны давай выйду из под руки.

# %%
torch.save(model, 'LSTM_BPE_4000.pt')

# %%
# YOUR CODE HERE (⊃｡•́‿•̀｡)⊃━✿✿✿✿✿✿
train_set = TextDataset(data_file='/kaggle/input/hw1rnn-data/jokes.txt', model_type='word', train=True, sp_model_prefix='unigram')
valid_set = TextDataset(data_file='/kaggle/input/hw1rnn-data/jokes.txt', model_type='word', train=False, sp_model_prefix='unigram')

train_loader = DataLoader(train_set, batch_size=64)
val_loader = DataLoader(valid_set, batch_size=64)

# %%
model_4 = LanguageModel(train_set, rnn_type=torch.nn.LSTM)
optimizer = torch.optim.Adam(model.parameters())

model.cuda()

# %%
train(
    model=model_4,
    optimizer=optimizer,
    scheduler=None,
    train_loader=train_loader,
    val_loader=val_loader,
    num_epochs=10
)

# %%
torch.save(model_4, 'LSTM_UNI.pt')

# %% [markdown]
# ## Задание 6. Latent Semantic Analysis (2 балла)
#
# Попробуем другой подход к оцениванию качества генерации, основанный на [Latent Semantic Analysis](https://en.wikipedia.org/wiki/Latent_semantic_analysis). Реализуйте следующую метрику и сравните по ней модели, обученные с разными токенизаторами:
#
# 1. Генерируем обученной моделью выборку текстов, совпадающую по размеру с валидационной выборкой.
# 2. Объединяем две выборки текстов (валидационную и сгенерированную) в один корпус. Обратите внимание, что наша токенизация в общем случае необратима, поэтому для чистоты эксперимента нужно закодировать и декодировать валидационную выборку.
# 3. Генерируем tf-idf матрицу для полученного корпуса.
# 4. Понижаем размерность матрицы с помощью [SVD](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.TruncatedSVD.html).
# 5. Теперь у нас есть векторы, описывающие валидационные и сгенерированные тексты, лежащие в одном пространстве. Для каждого вектора, отвечающего сгенерированному тексту, найдем наибольший cosine similarity между ним и вектором валидационного текста. Усредним такие similarity по всем сгенерированным текстам и получим число, характеризующее похожесть сгенерированной выборки на валидационную.
#
# Какие плюсы и минусы есть у описанной метрики?

# %%
# YOUR CODE HERE (⊃｡•́‿•̀｡)⊃━✿✿✿✿✿✿

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from tqdm.auto import tqdm


def LSA(model_path, data_file, vocab_size, sp_model_prefix):
    model = torch.load(model_path)
    model.cuda()

    X_val = TextDataset(data_file=data_file, vocab_size=vocab_size, train=False, sp_model_prefix=sp_model_prefix)

    X_val_real = X_val.ids2text(X_val.indices)
    X_val_generated = [model.inference() for i in tqdm(range(len(X_val)))]


    X_val_full = X_val_real + X_val_generated


    vectorizer = TfidfVectorizer()
    X = vectorizer.fit_transform(X_val_full)

    svd = TruncatedSVD(n_components=50, random_state=42)
    X_svd = svd.fit_transform(X)

    split = len(X_val_real)

    real_vecs = X_svd[:split, :]
    generated_vecs = X_svd[split:, :]

    cosine = cosine_similarity(generated_vecs, real_vecs).max(axis=1).mean()
    return cosine, real_vecs, generated_vecs

# %%
models = ['LSTM.pt', 'LSTM_BPE_4000.pt', 'LSTM_UNI.pt', 'RNN.pt']
prefixes = ['bpe', 'bpe_4000', 'unigram', 'bpe']
real_vecs = []
generated_vecs = []
for model_name, prefix in zip(models, prefixes):
    score, real, generated = LSA(
        model_path='/kaggle/input/hw1rnn-data/' + model_name,
        data_file='/kaggle/input/hw1rnn-data/jokes.txt',
        vocab_size=10,
        sp_model_prefix=prefix
    )
    real_vecs.append(real)
    generated_vecs.append(generated)

    print(model_name, score)

# %% [markdown]
# ## Задание 7. Visualization (1 балл)
#
# В прошлом пункте мы получили векторы, описывающие валидационные и сгенерированные тексты. Попробуем визуализировать их. Примените [TSNE](https://scikit-learn.org/stable/modules/generated/sklearn.manifold.TSNE.html) к этим векторам и нарисуйте scatter-plot с получившимися двумерными представлениями. Точки, соответствующие валидационным и сгенерированным текстам, должны быть разного цвета. Визуализируйте таким образом все три модели для разных токенизаторов.

# %%
# YOUR CODE HERE (⊃｡•́‿•̀｡)⊃━✿✿✿✿✿✿
from sklearn.manifold import TSNE
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


sns.set_style('whitegrid')
plt.rcParams.update({'font.size': 15})

# %%
models = ['LSTM.pt', 'LSTM_BPE_4000.pt', 'LSTM_UNI.pt', 'RNN.pt']


for i, name in enumerate(models):

    real = real_vecs[i]
    gen = generated_vecs[i]

    idx1 = np.random.randint(gen.shape[0], size=100)
    idx2 = np.random.randint(real.shape[0], size=100)

    data = np.concatenate((gen[idx1, :], real[idx2, :]), axis=0)
    tsne = TSNE(n_components=2, init='pca', learning_rate='auto')

    data_embedded = tsne.fit_transform(data)

    df = pd.DataFrame({
        'x': data_embedded[:, 0],
        'y': data_embedded[:, 1],
        'type': ['gen'] * 100 + ['real'] * 100
    })

    ax = sns.scatterplot(data=df, x="x", y="y", hue="type")
    ax.set_title(name.replace('.pt', ''))
    plt.show()

# %% [markdown]
# ## Задание 8. ruGPT perplexity (3.5 балла)
#
# Подход Latent Semantic Analysis, как и многие другие классические методы, заметно уступает нейросетевым алгоритмам анализа текстов. Вернемся к оцениванию качества генерации с помощью perplexity, для этого возьмем большую и хорошо обученную языковую модель, которая училась на огромном корпусе русских текстов. Считается, что большие языковые модели хорошо выучивают естественный язык, потому с их помощью мы сможем оценивать качество наших маленьких моделей для генерации анекдотов. Для этого мы воспользуемся сервисом [HuggingFace](https://huggingface.co/), который содержит огромное число обученных моделей для самых разных задач. Изучите и реализуйте, [подсчет perplexity](https://huggingface.co/docs/transformers/perplexity), с использованием обученной языковой модели. В качестве модели возьмите [ruGPT3-small](https://huggingface.co/sberbank-ai/rugpt3small_based_on_gpt2). Сгенерируйте синтетические выборки тремя моделями, обученными выше (можете взять выборки из задания 6), и сравните их по perplexity.

# %%
# YOUR CODE HERE (⊃｡•́‿•̀｡)⊃━✿✿✿✿✿✿
from transformers import AutoTokenizer, AutoModelForCausalLM
model = AutoModelForCausalLM.from_pretrained("ai-forever/rugpt3small_based_on_gpt2")
tokenizer = AutoTokenizer.from_pretrained("ai-forever/rugpt3small_based_on_gpt2")

model.cuda()

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device

# %%
def gpt_perplexity(encodings):
    max_length = model.config.n_positions
    stride = 512
    seq_len = encodings.input_ids.size(1)
    sample_size=1000

    nlls = []
    prev_end_loc = 0
    for begin_loc in range(0, seq_len, stride):
        end_loc = min(begin_loc + max_length, seq_len)
        trg_len = end_loc - prev_end_loc  # may be different from stride on last loop
        input_ids = encodings.input_ids[:, begin_loc:end_loc].to(device)
        target_ids = input_ids.clone()
        target_ids[:, :-trg_len] = -100

        with torch.no_grad():
            outputs = model(input_ids, labels=target_ids)

            # loss is calculated using CrossEntropyLoss which averages over valid labels
            # N.B. the model only calculates loss over trg_len - 1 labels, because it internally shifts the labels
            # to the left by 1.
            neg_log_likelihood = outputs.loss

        nlls.append(neg_log_likelihood)

        prev_end_loc = end_loc
        if end_loc == seq_len:
            break
    ppl = torch.exp(torch.stack(nlls).mean())

    return ppl.item()

# %%
models = ['LSTM.pt', 'LSTM_BPE_4000.pt', 'LSTM_UNI.pt', 'RNN.pt']
for i in tqdm(models):
    language_model = torch.load('/kaggle/input/hw1rnn-data/'+i)

    generated = [language_model.inference() for i in range(1000)]
    encodings = tokenizer("\n\n".join(generated), return_tensors="pt")

    ppl = gpt_perplexity(encodings)
    print(i.replace('.pt', ''), ppl)

# %% [markdown]
# ## Бонус (0.1 балл)
#
# Покажите лучший анекдот, который удалось сгенерировать вашей модели. Если проверяющий найдет его смешным, то поставит 0.1 балла.
